# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
bar_order = ["Dream", "Torgersen", "Biscoe"]

sns.barplot(
    x="island", 
    y="bill_length_mm", 
    data=df, 
    hue="sex", 
    order=bar_order, 
    hue_order=["Female", "Male"],
    errorbar=('ci', 1)
)

plt.show()

# %%
# Changing the order of the bar

bar_order = ["Dream", "Torgersen", "Biscoe"]

sns.barplot(
    x="island", 
    y="bill_length_mm", 
    data=df, 
    hue="sex", 
    order=bar_order, 
    hue_order=["Female", "Male"],
    errorbar=('ci', 1)
)

plt.show()

# %%
# For horizenttal bar

sns.barplot(
      x="bill_depth_mm", 
      y="bill_length_mm", 
      data=df,
      orient="h"
)

plt.show()

# %%
# For colors

sns.barplot(
      x="island", 
      y="bill_length_mm", 
      data=df,
      hue="sex",
      palette="turbo_r",
)

plt.show()

# %%
# saturation of the bars/color of the error

sns.barplot(
      x="island", 
      y="bill_length_mm", 
      data=df,
      hue="sex",
      palette="turbo_r",
      saturation=0.5,
      errcolor='b'
)

plt.show()
# Out:
# C:\Users\hritik\AppData\Local\Temp\ipykernel_19584\2107066709.py:3: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'b'}` instead.
#
#   sns.barplot(
